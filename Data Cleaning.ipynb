# %% [markdown]
# # Red and white wine data exploration

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Reading the data from csv: red wine = red;  white wine = white

# %%
red = pd.read_csv('data/winequality-red.csv', sep = ';')
white = pd.read_csv('data/winequality-white.csv', sep = ';')

# %% [markdown]
# ### Data exploration

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
red.quality.mean() #5.62
# Out:
# 5.6360225140712945

# %%
white.quality.mean() #5.85
# Out:
# 5.87790935075541

# %% [markdown]
# ### Looking at the distribution of customer ratings between red and white wine

# %%
fig, ax = plt.subplots(figsize=(10, 6))
 
sns.kdeplot(data=red.quality, ax=ax, color='purple', shade=True, label='Red')
sns.kdeplot(data=white.quality, ax=ax, color='green', shade=True, label='White')

ax.set_title('Distribution of Customer Quality Ratings')
ax.set_xlabel('Rating')
ax.set_ylabel('Density')

ax.legend()
plt.show()

# %% [markdown]
# ### Looking at correlations

# %%
red.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# RED WINE

fig, ax = plt.subplots(figsize=(18, 9))

sns.heatmap(red.corr(), annot=True)


# 0.5 alcohol & quality
# -0.4 volatile acidity & quality


# -0.7 ph & volatile acidity
# 0.7 citric acid & volatile acidity 
# 0.7 density & volatile acidity
# -0.5 ph & citric acid
# 0.67 free sulfur dioxide & total sulfur dioxide
# Out:
# <AxesSubplot:>

# %%
white.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# WHITE WINE

fig, ax = plt.subplots(figsize=(18, 9))

sns.heatmap(white.corr(), annot=True)

# 0.44 alcohol & quality


# -0.78 density & alcohol
# 0.84 density & residual sugar
# 0.53 density & total sulfur dioxide
# 0.62 free sulfur dioxide & total sulfur dioxide
# 0.43 ph & fixed acidity
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Renaming columns

# %%
#Using a function to rename the columns in both data sets to include underscores 
def rename_columns(x):
    x.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity', "citric acid":"citric_acid", 
                          'residual sugar':'residual_sugar', "free sulfur dioxide":"free_sulfur_dioxide",
                      "total sulfur dioxide":"total_sulfur_dioxide", }, inplace=True )
    return x

# %%
#running the function above
rename_columns(red) 
rename_columns(white)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Finding duplicates and removing

# %%
red.shape
# Out:
# (1599, 12)

# %%
red = red.drop_duplicates()

# %%
white.shape
# Out:
# (4898, 12)

# %%
white = white.drop_duplicates()

# %% [markdown]
# ### Finding NaNs

# %%
red.isnull().values.any()
# Out:
# False

# %%
white.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Looking at boxplots to visualize the outliers

# %%
#all boxplots together 

plt.figure(figsize=(23, 15))
red.boxplot()
plt.show()

# %% [markdown]
# ### Taking a closer look at histograms

# %%
fig, axs = plt.subplots(ncols=3, figsize=(25,5))

sns.color_palette("Set2")

sns.boxplot(x='fixed_acidity', data=red, ax=axs[0], palette="Set2")
sns.boxplot(x='volatile_acidity', data=red, ax=axs[1], palette="Set2")
sns.boxplot(x='citric_acid', data=red, ax=axs[2], palette="Set2")
# Out:
# <AxesSubplot:xlabel='citric_acid'>

# %%
fig, axs = plt.subplots(ncols=3, figsize=(25,5))

sns.boxplot(x='residual_sugar', data=red, ax=axs[0], palette="Blues")
sns.boxplot(x='chlorides', data=red, ax=axs[1], palette="Blues")
sns.boxplot(x='free_sulfur_dioxide', data=red, ax=axs[2], palette="Blues")
# Out:
# <AxesSubplot:xlabel='free_sulfur_dioxide'>

# %%
fig, axs = plt.subplots(ncols=3, figsize=(25,5))
sns.color_palette("husl", 8)
sns.boxplot(x='total_sulfur_dioxide', data=red, ax=axs[0], palette="husl")
sns.boxplot(x='density', data=red, ax=axs[1], palette="husl")
sns.boxplot(x='pH', data=red, ax=axs[2], palette="husl")
# Out:
# <AxesSubplot:xlabel='pH'>

# %%
fig, axs = plt.subplots(ncols=3, figsize=(25,5))
sns.color_palette("Paired")

sns.boxplot(x='sulphates', data=red, ax=axs[0], palette="Paired")
sns.boxplot(x='alcohol', data=red, ax=axs[1], palette="Paired")
sns.boxplot(x='quality', data=red, ax=axs[2], palette="Paired")
# Out:
# <AxesSubplot:xlabel='quality'>

# %% [markdown]
# ### Removing outliers

# %%
from scipy.stats import iqr
def remove_outliers(df):
    for c in df.columns:
            pct_95 = np.percentile(df[c], 95)
            pct_5 = np.percentile(df[c], 5)
            upper_bound = pct_95 + 1.9*iqr(df[c])
            lower_bound = pct_5 - 1.9*iqr(df[c])
            condition = (df[c] < upper_bound) & (df[c] > lower_bound)
            df[c] = df[c][condition]  # Filter out the outliers
    return df

# %%
remove_outliers(white)
remove_outliers(red)
# Out:
# C:\Users\Monika\AppData\Local\Temp\ipykernel_16944\967903317.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c] = df[c][condition]  # Filter out the outliers
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# ...

# %% [markdown]
# ### Checking whether outliers were removed

# %%
#red wine describe before: total sulfur dioxide min: 6.0 max: 289
red.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1358.000000       1356.000000  1359.000000     1323.000000
# mean        8.305007          0.527522     0.272333        2.355896
# std         1.725364          0.178355     0.195537        0.784809
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.600000          1.240000     1.000000        6.100000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1315.000000          1356.000000           1357.000000  1359.000000
# mean      0.080786            15.776549             46.477155     0.996709
# std       0.019761            10.158424             32.171729     0.001869
# ...

# %%
#white wine desc before: total sulfur dioxide min: 9.0 max: 440 
white.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    3956.000000       3939.000000  3941.000000     3959.000000
# mean        6.833506          0.277616     0.331276        5.893205
# std         0.850068          0.095649     0.114075        4.751245
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.320000     0.390000        8.800000
# max        10.200000          0.685000     0.740000       26.050000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  3859.000000          3948.000000           3958.000000  3959.000000
# mean      0.042855            34.563070            137.006822     0.993774
# std       0.011490            16.051916             42.593696     0.002803
# ...

# %% [markdown]
# ### Locating NaNs after outlier removal

# %%
red[red.isna().any(axis=1)]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 13              7.8             0.610         0.29             1.6      0.114
# 17              8.1             0.560         0.28             1.7        NaN
# 19              7.9             0.320         0.51             1.8        NaN
# 33              6.9             0.605         0.12             NaN      0.073
# 42              7.5             0.490         0.20             2.6        NaN
# ...             ...               ...          ...             ...        ...
# 1505            6.7             0.760         0.02             1.8      0.078
# 1558            6.9             0.630         0.33             NaN        NaN
# 1570            6.4             0.360         0.53             2.2        NaN
# 1574            5.6             0.310         0.78             NaN      0.074
# 1589            6.6             0.725         0.20             NaN      0.073
#
# ...

# %%
white[white.isna().any(axis=1)]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 40              6.7              0.23         0.39             2.5        NaN
# 41              6.7              0.24         0.39             2.9        NaN
# 54              6.8              0.20         0.59             0.9        NaN
# 194             6.4              0.29         0.44             3.6        NaN
# 195             6.4              0.30         0.45             3.5        NaN
# ...             ...               ...          ...             ...        ...
# 4794            6.0              0.32         0.30             7.3        NaN
# 4813            5.8              0.36         0.50             1.0        NaN
# 4815            6.2               NaN         0.01             3.2      0.041
# 4845            6.6              0.38         0.29             2.4        NaN
# 4886            6.2              0.21         0.28             5.7      0.028
#
# ...

# %% [markdown]
# ### Dropping rows with NaNs

# %%
white_new = white.dropna()

# %%
white_new.isnull().values.any()
# Out:
# False

# %%
white_new
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_new = red.dropna()

# %%
red_new
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Histograms for visualisation

# %%
red_new.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed_acidity'}>,
#         <AxesSubplot:title={'center':'volatile_acidity'}>,
#         <AxesSubplot:title={'center':'citric_acid'}>],
#        [<AxesSubplot:title={'center':'residual_sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free_sulfur_dioxide'}>],
#        [<AxesSubplot:title={'center':'total_sulfur_dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
white_new.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed_acidity'}>,
#         <AxesSubplot:title={'center':'volatile_acidity'}>,
#         <AxesSubplot:title={'center':'citric_acid'}>],
#        [<AxesSubplot:title={'center':'residual_sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free_sulfur_dioxide'}>],
#        [<AxesSubplot:title={'center':'total_sulfur_dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %% [markdown]
# ### Saving the cleaned data to csv

# %%
#red_new.to_csv('data/red_final.csv')
#white_new.to_csv('data/white_final.csv')
