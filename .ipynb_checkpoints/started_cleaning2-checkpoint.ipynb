# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %%
red = pd.read_csv('data/winequality-red.csv', sep = ';')
white = pd.read_csv('data/winequality-white.csv', sep = ';')

# %%
red.describe()
# need to rename the columns
# mean quality = 5.6

# %%
white.describe()
# mean quality 5.9

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# Create a figure 
fig, ax = plt.subplots(figsize=(8, 4))
 
# Plot the KDEs for red and white in the same subplot
sns.kdeplot(data=red.quality, ax=ax, color='red', shade=True, label='Red')
sns.kdeplot(data=white.quality, ax=ax, color='yellow', shade=True, label='White')


# Set the title and axis labels for the subplot
ax.set_title('Distribution of Quality')
ax.set_xlabel('Rating')
ax.set_ylabel('Density')

# Add a legend for the KDEs
ax.legend()

# Show the plot
plt.show()

# %%
red.corr()

# %%
# RED WINE

fig, ax = plt.subplots(figsize=(18, 9))

sns.heatmap(red.corr(), annot=True)


# 0.5 alcohol & quality
# -0.4 volatile acidity & quality


# -0.7 ph & volatile acidity
# 0.7 citric acid & volatile acidity 
# 0.7 density & volatile acidity
# -0.5 ph & citric acid
# 0.67 free sulfur dioxide & total sulfur dioxide

# %%
# WHITE WINE

fig, ax = plt.subplots(figsize=(18, 9))

sns.heatmap(white.corr(), annot=True)

# 0.44 alcohol & quality


# -0.78 density & alcohol
# 0.84 density & residual sugar
# 0.53 density & total sulfur dioxide
# 0.62 free sulfur dioxide & total sulfur dioxide
# 0.43 ph & fixed acidity

# %%
sns.histplot(red)

# %% [markdown]
# # Look at descriptive statistics

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996700
# 75%       0.091000            21.000000             63.000000     0.997820
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1359.000000  1359.000000  1359.000000  1359.000000
# mean      3.309787     0.658705    10.432315     5.623252
# std       0.155036     0.170667     1.082065     0.823578
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red_without_nan.describe()
# Out:
#        fixed_acidity  volatile_acidity  residual_sugar    chlorides  \
# count    1270.000000       1270.000000     1270.000000  1270.000000
# mean        8.307795          0.528476        2.370433     0.080777
# std         1.744448          0.178690        0.792079     0.019578
# min         4.600000          0.120000        0.900000     0.034000
# 25%         7.100000          0.390000        1.900000     0.070000
# 50%         7.900000          0.520000        2.200000     0.079000
# 75%         9.200000          0.640000        2.600000     0.089000
# max        15.600000          1.240000        6.100000     0.176000
#
#        free_sulfur_dioxide  total_sulfur_dioxide      density           pH  \
# count          1270.000000           1270.000000  1270.000000  1270.000000
# mean             15.718504             45.732677     0.996666     3.316236
# std              10.038210             31.443402     0.001834     0.149317
# min               1.000000              6.000000     0.990070     2.860000
# 25%               7.000000             22.000000     0.995553     3.220000
# 50%              13.500000             37.500000     0.996680     3.310000
# 75%              21.000000             61.000000     0.997800     3.407500
# max              57.000000            165.000000     1.003200     3.900000
#
#          sulphates  citric_acid      alcohol      quality
# count  1270.000000  1270.000000  1270.000000  1270.000000
# mean      0.644717     0.265031    10.444816     5.628346
# std       0.134993     0.191708     1.065707     0.816776
# min       0.330000     0.000000     8.400000     3.000000
# 25%       0.550000     0.090000     9.500000     5.000000
# 50%       0.620000     0.250000    10.200000     6.000000
# 75%       0.720000     0.420000    11.100000     6.000000
# max       1.220000     0.790000    14.000000     8.000000

# %%
red_without_nan.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed_acidity'}>,
#         <AxesSubplot:title={'center':'volatile_acidity'}>,
#         <AxesSubplot:title={'center':'residual_sugar'}>],
#        [<AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free_sulfur_dioxide'}>,
#         <AxesSubplot:title={'center':'total_sulfur_dioxide'}>],
#        [<AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'sulphates'}>],
#        [<AxesSubplot:title={'center':'citric_acid'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %% [markdown]
# # Look at distributions

# %%
# r
sns.histplot(red['fixed acidity'], kde=True, color = 'red')

# %%
sns.histplot(white['fixed_acidity'], kde=True, color = 'lightblue')

# %%
red.hist(figsize = (15,15))

# %% [markdown]
# # Clean the data

# %% [markdown]
# ## Rename columns

# %%
#function to rename the column names 
def rename_columns(x):
    x.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity', "citric acid":"citric_acid", 
                          'residual sugar':'residual_sugar', "free sulfur dioxide":"free_sulfur_dioxide",
                      "total sulfur dioxide":"total_sulfur_dioxide", }, inplace=True )
    return x

# %%
rename_columns(red) #running the function above
rename_columns(white) #running the function above
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 6         9.6        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [3961 rows x 12 columns]

# %% [markdown]
# ## Find duplicates

# %%
red.shape

# %%
test_red.shape

# %%
red = red.drop_duplicates()

# %%
white.shape

# %%
white = white.drop_duplicates()

# %% [markdown]
# ## Find & Drop NaN

# %%
# red_concatenated[red_concatenated.isna().any(axis=1)]

# %%
red_without_nan = red_concatenated.dropna()

# %%
white_without_nan = white_concatenated.dropna()

# %%
white_concatenated[white_concatenated.isna().any(axis=1)]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 40              6.7              0.23         0.39             2.5        NaN
# 41              6.7              0.24         0.39             2.9        NaN
# 54              6.8              0.20         0.59             0.9        NaN
# 194             6.4              0.29         0.44             3.6        NaN
# 195             6.4              0.30         0.45             3.5        NaN
# ...             ...               ...          ...             ...        ...
# 4794            6.0              0.32         0.30             7.3        NaN
# 4813            5.8              0.36         0.50             1.0        NaN
# 4815            6.2               NaN         0.01             3.2      0.041
# 4845            6.6              0.38         0.29             2.4        NaN
# 4886            6.2              0.21         0.28             5.7      0.028
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 40                   63.0                 158.0  0.99370  3.11       0.36
# 41                   63.0                 157.0  0.99370  3.10       0.34
# 54                   38.0                 132.0  0.99300  3.05       0.38
# 194                  75.0                 181.0  0.99420  3.02       0.41
# 195                  76.0                 180.0  0.99420  3.02       0.39
# ...                   ...                   ...      ...   ...        ...
# 4794                 46.0                 159.0  0.99519  3.18       0.49
# 4813                 63.0                 178.0  0.99212  3.10       0.45
# 4815                 18.0                 120.0  0.99026  3.20       0.94
# 4845                 15.0                  93.0  0.99336  3.18       0.60
# 4886                 45.0                 121.0  0.99168  3.21        NaN
#
#       alcohol  quality
# 40       9.40        6
# 41       9.40        6
# 54       9.10        6
# 194      9.10        5
# 195      9.10        6
# ...       ...      ...
# 4794     9.40        5
# 4813     9.70        5
# 4815    13.70        7
# 4845     9.50        5
# 4886    12.15        7
#
# [166 rows x 12 columns]

# %%
white.isnull().values.any()
# Out:
# False

# %%
white_without_nan.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Get rid of the outliers

# %% [markdown]
# ## Check for outliers

# %%
red.columns

# %%
plt.boxplot(red.fixed_acidity)

# %%
plt.boxplot(red.fixed_acidity)

# %%
plt.boxplot(red.volatile_acidity)

# %%
plt.boxplot(red.volatile_acidity)

# %%
plt.boxplot(red.citric_acid)

# %%
plt.boxplot(red.residual_sugar)

# %%
plt.boxplot(red.chlorides)

# %%
plt.boxplot(red.free_sulfur_dioxide)

# %%
plt.boxplot(red.total_sulfur_dioxide)

# %%
plt.boxplot(red.density)

# %%
plt.boxplot(red.pH)

# %%
plt.boxplot(red.sulphates)

# %%
plt.boxplot(red.alcohol)

# %%
plt.boxplot(red.quality)

# %%
red_without_nan.to_csv('data/red_cleaned_final.csv')

# %%
white_without_nan.to_csv('data/white_cleaned_final.csv')

# %%
red.columns

# %%
red_1 = red.drop(['citric_acid', 'alcohol', 'quality'], axis = 1)

# %%
red_1

# %%
white_1 = white.drop(['alcohol', 'quality'], axis = 1)

# %%
red_2 = red.drop(['fixed_acidity', 'volatile_acidity', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
                  'total_sulfur_dioxide', 'density', 'pH', 'sulphates'], axis = 1)

# %%
red_2

# %%
white_2 = white.drop(['citric_acid','fixed_acidity', 'volatile_acidity', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
                  'total_sulfur_dioxide', 'density', 'pH', 'sulphates'], axis = 1)

# %%
from scipy.stats import iqr
def remove_outliers(df):
    for c in df.columns:
            pct_95 = np.percentile(df[c], 95)
            pct_5 = np.percentile(df[c], 5)
            upper_bound = pct_95 + 1.9*iqr(df[c])
            lower_bound = pct_5 - 1.9*iqr(df[c])
            condition = (df[c] < upper_bound) & (df[c] > lower_bound)
            df[c] = df[c][condition]  # Filter out the outliers
    return df

# %%
red_1 = remove_outliers(red_1)

# %%
white_1 = remove_outliers(white_1)

# %%
red_concatenated = pd.concat([red_1, red_2], axis = 1)

# %%
white_concatenated = pd.concat([white_1, white_2], axis = 1)

# %%
red_concatenated
# Out:
#       fixed_acidity  volatile_acidity  residual_sugar  chlorides  \
# 0               7.4             0.700             1.9      0.076
# 1               7.8             0.880             2.6      0.098
# 2               7.8             0.760             2.3      0.092
# 3              11.2             0.280             1.9      0.075
# 5               7.4             0.660             1.8      0.075
# ...             ...               ...             ...        ...
# 1593            6.8             0.620             1.9      0.068
# 1594            6.2             0.600             2.0      0.090
# 1595            5.9             0.550             2.2      0.062
# 1597            5.9             0.645             2.0      0.075
# 1598            6.0             0.310             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       citric_acid  alcohol  quality
# 0            0.00      9.4        5
# 1            0.00      9.8        5
# 2            0.04      9.8        5
# 3            0.56      9.8        6
# 5            0.00      9.4        5
# ...           ...      ...      ...
# 1593         0.08      9.5        6
# 1594         0.08     10.5        5
# 1595         0.10     11.2        6
# 1597         0.12     10.2        5
# 1598         0.47     11.0        6
#
# [1359 rows x 12 columns]

# %%
white.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.035000            23.000000            106.000000     0.991620
# 50%       0.042000            33.000000            133.000000     0.993500
# 75%       0.050000            45.000000            166.000000     0.995710
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  3961.000000  3961.000000  3961.000000  3961.000000
# mean      3.195458     0.490351    10.589358     5.854835
# std       0.151546     0.113523     1.217076     0.890683
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.480000    10.400000     6.000000
# 75%       3.290000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
white_concatenated.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    3956.000000       3939.000000  3941.000000     3959.000000
# mean        6.833506          0.277616     0.331276        5.893205
# std         0.850068          0.095649     0.114075        4.751245
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.320000     0.390000        8.800000
# max        10.200000          0.685000     0.740000       26.050000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  3859.000000          3948.000000           3958.000000  3959.000000
# mean      0.042855            34.563070            137.006822     0.993774
# std       0.011490            16.051916             42.593696     0.002803
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.035000            23.000000            106.000000     0.991615
# 50%       0.042000            33.000000            133.000000     0.993500
# 75%       0.049000            45.000000            166.000000     0.995700
# max       0.097000           101.000000            313.000000     1.002950
#
#                 pH    sulphates      alcohol      quality
# count  3961.000000  3952.000000  3961.000000  3961.000000
# mean      3.195458     0.489178    10.589358     5.854835
# std       0.151546     0.110940     1.217076     0.890683
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.480000    10.400000     6.000000
# 75%       3.290000     0.550000    11.400000     6.000000
# max       3.820000     0.960000    14.200000     9.000000

# %% [markdown]
# # Powertransformer

# %%
red_without_nan.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'residual_sugar', 'chlorides',
#        'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH',
#        'sulphates', 'citric_acid', 'alcohol', 'quality'],
#       dtype='object')

# %%
power = PowerTransformer(method='yeo-johnson', standardize=True)
red_trans = power.fit_transform(red_without_nan)
#red = np.reshape(red_without_nan(-1,1))
#df_reshaped = pd.red_without_nan(np.array(df['sales']).reshape(1, -1), columns=df['date'])

# %%
type(red_trans)
# Out:
# numpy.ndarray

# %%
red_trans_df = pd.DataFrame(red_trans)

# %%
red_trans_df
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.432854  0.989153 -0.614414 -0.136039 -0.274309 -0.115872  0.618863
# 1    -0.155673  1.768942  0.630737  0.990876  1.016658  0.878460  0.073411
# 2    -0.155673  1.264406  0.186421  0.717829  0.195644  0.558219  0.182510
# 3     1.523271 -1.545424 -0.614414 -0.196228  0.391562  0.714190  0.727940
# 4    -0.432854  0.796116 -0.865650 -0.196228 -0.023993  0.118857  0.618863
# ...        ...       ...       ...       ...       ...       ...       ...
# 1265 -0.896495  0.594852 -0.614414 -0.642928  1.206273  0.044520 -0.084791
# 1266 -1.429442  0.490960 -0.386159  0.621501  1.433038  0.257584 -0.963256
# 1267 -1.727161  0.221110  0.012068 -1.063833  1.775534  0.473970 -0.843200
# 1268 -1.727161  0.721635 -0.386159 -0.196228  1.433038  0.257584 -0.652213
# 1269 -1.625360 -1.318208  1.568493 -0.710541  0.482189  0.189776 -0.641300
#
#             7         8         9         10        11
# 0     1.282506 -0.583863 -1.515257 -1.107678 -0.757076
# 1    -0.769308  0.446502 -1.515257 -0.528515 -0.757076
# 2    -0.352738  0.219364 -1.237349 -0.528515 -0.757076
# 3    -1.052593 -0.387744  1.440372 -0.528515  0.481095
# 4     1.282506 -0.583863 -1.515257 -1.107678 -0.757076
# ...        ...       ...       ...       ...       ...
# 1265  0.711655  1.302872 -0.973201 -0.953024  0.481095
# 1266  0.904084 -0.387744 -0.973201  0.271631 -0.757076
# 1267  1.344759  0.972370 -0.845921  0.871259  0.481095
# 1268  1.652601  0.656454 -0.721658 -0.042481 -0.757076
# 1269  0.517030  0.297090  1.069311  0.716608  0.481095
#
# [1270 rows x 12 columns]

# %%
# create histogram of transformed data
plt.hist(red_trans.fixed_acidity, bins=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wq/2vxkh_6d4g7dpxkr5q82nxzh0000gn/T/ipykernel_81564/4218489136.py in <module>
#       1 # create histogram of transformed data
# ----> 2 plt.hist(red_trans.fixed_acidity, bins=50)
#       3 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'fixed_acidity'

# %%
red_trans.hist(figsize = (15,15))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wq/2vxkh_6d4g7dpxkr5q82nxzh0000gn/T/ipykernel_81564/4291250171.py in <module>
# ----> 1 red_trans.hist(figsize = (15,15))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'

# %%
red_without_nan
# Out:
#       fixed_acidity  volatile_acidity  residual_sugar  chlorides  \
# 0               7.4             0.700             1.9      0.076
# 1               7.8             0.880             2.6      0.098
# 2               7.8             0.760             2.3      0.092
# 3              11.2             0.280             1.9      0.075
# 5               7.4             0.660             1.8      0.075
# ...             ...               ...             ...        ...
# 1593            6.8             0.620             1.9      0.068
# 1594            6.2             0.600             2.0      0.090
# 1595            5.9             0.550             2.2      0.062
# 1597            5.9             0.645             2.0      0.075
# 1598            6.0             0.310             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       citric_acid  alcohol  quality
# 0            0.00      9.4        5
# 1            0.00      9.8        5
# 2            0.04      9.8        5
# 3            0.56      9.8        6
# 5            0.00      9.4        5
# ...           ...      ...      ...
# 1593         0.08      9.5        6
# 1594         0.08     10.5        5
# 1595         0.10     11.2        6
# 1597         0.12     10.2        5
# 1598         0.47     11.0        6
#
# [1270 rows x 12 columns]

# %%
red_without_nan.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed_acidity'}>,
#         <AxesSubplot:title={'center':'volatile_acidity'}>,
#         <AxesSubplot:title={'center':'residual_sugar'}>],
#        [<AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free_sulfur_dioxide'}>,
#         <AxesSubplot:title={'center':'total_sulfur_dioxide'}>],
#        [<AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'sulphates'}>],
#        [<AxesSubplot:title={'center':'citric_acid'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
pt = PowerTransformer()
free_sulfur_dio_trans = pt.fit_transform(red_without_nan['free_sulfur_dioxide'].to_numpy().reshape(-1,1))
sns.displot(free_sulfur_dio_trans, kde=True)
sns.displot(red_without_nan.free_sulfur_dioxide)

# %%
total_sulfur_dio_trans = pt.fit_transform(red_without_nan['total_sulfur_dioxide'].to_numpy().reshape(-1,1))
sns.displot(total_sulfur_dio_trans, kde=True)
sns.displot(red_without_nan.total_sulfur_dioxide)

# %%
residual_sugar_trans = pt.fit_transform(red_without_nan['residual_sugar'].to_numpy().reshape(-1,1))
sns.displot(residual_sugar_trans, kde=True)
sns.displot(red_without_nan.residual_sugar)

# %%
chlorides_trans = pt.fit_transform(red_without_nan['chlorides'].to_numpy().reshape(-1,1))
sns.displot(chlorides_trans, kde=True)
sns.displot(red_without_nan.chlorides)

# %%
citric_acid_trans = pt.fit_transform(red_without_nan['citric_acid'].to_numpy().reshape(-1,1))
sns.displot(citric_acid_trans, kde=True)
sns.displot(red_without_nan.citric_acid)

# %%
#volatile acidity
volatile_acidity_trans = pt.fit_transform(red_without_nan['volatile_acidity'].to_numpy().reshape(-1,1))
sns.displot(volatile_acidity_trans, kde=True)
sns.displot(red_without_nan.volatile_acidity)

# %%
#fixed acidity
#before transformation
#after transformation
fixed_acidity_trans = pt.fit_transform(red_without_nan['fixed_acidity'].to_numpy().reshape(-1,1))
sns.displot(fixed_acidity_trans, kde=True)
sns.displot(red_without_nan.fixed_acidity)

# %%
#alcohol
#before transformation
#after transformation
alcohol_trans = pt.fit_transform(red_without_nan['alcohol'].to_numpy().reshape(-1,1))
sns.displot(alcohol_trans, kde=True)
sns.displot(red_without_nan.alcohol)

# %%
#sulphates
#before transformation
#after transformation
sulphates_trans = pt.fit_transform(red_without_nan['sulphates'].to_numpy().reshape(-1,1))
sns.displot(sulphates_trans, kde=True)
sns.displot(red_without_nan.sulphates)

# %% [markdown]
# # Standard Scaler

# %%
scaler = StandardScaler()
ph_scaled = scaler.fit_transform(red_without_nan['pH'].to_numpy().reshape(-1,1))
sns.displot(ph_scaled, kde=True)
sns.displot(red_without_nan.pH)

# %%
density_scaled = scaler.fit_transform(red_without_nan['density'].to_numpy().reshape(-1,1))
sns.displot(density_scaled, kde=True)
sns.displot(red_without_nan.density)

# %%
sns.displot(red_without_nan.quality, kde = True)

# %%
from scipy.stats import kstest
test_stat, p_value = kstest(red_without_nan.sulphates, 'norm')
print('Test statistic:', test_stat)
print('P-value:', p_value)
# Out:
# Test statistic: 0.6577407620817076
# P-value: 0.0

# %%
from scipy.stats import shapiro
test_stat, p_value = shapiro(red_without_nan.density)
print('Test statistic:', test_stat)
print('P-value:', p_value)
# Out:
# Test statistic: 0.9939444661140442
# P-value: 4.908995106234215e-05

# %%
plt.hist(red_without_nan.density)
# Out:
# (array([  5.,  22.,  68., 170., 362., 360., 177.,  81.,  19.,   6.]),
#  array([0.99007 , 0.991383, 0.992696, 0.994009, 0.995322, 0.996635,
#         0.997948, 0.999261, 1.000574, 1.001887, 1.0032  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(red_without_nan.quality)
# Out:
# /Users/dmitrir./opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality'>

# %%
quality_scaled = scaler.fit_transform(red_without_nan['quality'].to_numpy().reshape(-1,1))
sns.displot(quality_scaled, kde=True)
sns.displot(red_without_nan.quality)

# %%
quality_trans = pt.fit_transform(red_without_nan['quality'].to_numpy().reshape(-1,1))
sns.displot(quality_trans, kde=True)
sns.displot(red_without_nan.quality)
